# %% [markdown]
# # <font face = 'Impact' color = '#1181C8' > Quick Keys in Visual Studio Code <font/>
# #### <font face = 'Times New Roman' color = '#213349'> Organized by: Paolo Hilado MSc. (Data Science) <font/>
# Presenting to you the Shadow scroll of Visual Studio Code quick keys. It is compact arsenal of shortcuts forged for speed, precision, and silent efficiency. Inside this notebook, every command is a swift strike, every key combo a stealth move designed to eliminate friction and keep you in flow. Master these shortcuts, and you won’t just write code… you’ll move through it like a shadow. 🥷⚡

# %% [markdown]
# ### <font face = 'Impact' color = '#1181C8' > Shadow Commands: Command Palette <font/>
# #### Every ninja needs eyes in every direction. The Command Palette is your secret scroll. It is a single strike to summon any tool, open any file, or execute any command instantly. Move silently, act swiftly, and never break your flow.
#
# | Action             | Windows / Linux     | macOS             |
# | ------------------ | ------------------- | ----------------- |
# | Command Palette    | `Ctrl + Shift + P`  | `Cmd + Shift + P` |
# | Quick Open (files) | `Ctrl + P`          | `Cmd + P`         |
# | Settings           | `Ctrl + ,`          | `Cmd + ,`         |
# | Keyboard Shortcuts | `Ctrl + K Ctrl + S` | `Cmd + K Cmd + S` |
# | Toggle Sidebar     | `Ctrl + B`          | `Cmd + B`         |
# | New Window         | `Ctrl + Shift + N`  | `Cmd + Shift + N` |
# | Close Window       | `Ctrl + Shift + W`  | `Cmd + Shift + W` |

# %% [markdown]
# ### <font face = 'Impact' color = '#1181C8' > Shadow Scroll: File Management <font/>
# #### Your code is your dojo, and each file is a hidden scroll. Master these moves to summon, close, or save your scrolls without hesitation. With precision and speed, you’ll navigate your codebase like a silent shadow, leaving no file unopened, no secret lost.
#
# | Action             | Windows / Linux    | macOS              |
# | ------------------ | ------------------ | ------------------ |
# | New File           | `Ctrl + N`         | `Cmd + N`          |
# | Open File          | `Ctrl + O`         | `Cmd + O`          |
# | Save               | `Ctrl + S`         | `Cmd + S`          |
# | Save All           | `Ctrl + K S`       | `Cmd + Option + S` |
# | Close File         | `Ctrl + W`         | `Cmd + W`          |
# | Reopen Closed File | `Ctrl + Shift + T` | `Cmd + Shift + T`  |

# %% [markdown]
# ### <font face = 'Impact' color = '#1181C8' > Blade of Precision - Coding & Editing <font/>
# #### Every line of code is a strike, every edit a masterful cut. With these moves, you slice through clutter, duplicate lines like shadow clones, and shape your code with the grace of a silent warrior. Precision, speed, and control... this is the way of the coding blade.
#
# | Action            | Windows / Linux        | macOS                 |
# | ----------------- | ---------------------- | --------------------- |
# | Copy Line Down    | `Shift + Alt + ↓`      | `Shift + Option + ↓`  |
# | Copy Line Up      | `Shift + Alt + ↑`      | `Shift + Option + ↑`  |
# | Move Line Down    | `Alt + ↓`              | `Option + ↓`          |
# | Move Line Up      | `Alt + ↑`              | `Option + ↑`          |
# | Delete Line       | `Ctrl + Shift + K`     | `Cmd + Shift + K`     |
# | Insert Line Below | `Ctrl + Enter`         | `Cmd + Enter`         |
# | Insert Line Above | `Ctrl + Shift + Enter` | `Cmd + Shift + Enter` |
# | Select Line       | `Ctrl + L`             | `Cmd + L`             |
# | Select All        | `Ctrl + A`             | `Cmd + A`             |
# | Undo              | `Ctrl + Z`             | `Cmd + Z`             |
# | Redo              | `Ctrl + Y`             | `Cmd + Shift + Z`     |

# %% [markdown]
# ### <font face = 'Impact' color = '#1181C8' > Phantom Strike - Selection and Multi-Cursor <font/>
# #### Why strike once when you can strike many? With the power of Phantom Strike, you can edit multiple lines at once, target all occurrences of a variable, and manipulate code like a true stealth warrior. Multiply your presence, multiply your impact and make sure no line escapes your reach.
#
# | Action                 | Windows / Linux      | macOS                   |
# | ---------------------- | -------------------- | ----------------------- |
# | Add Cursor Below       | `Ctrl + Alt + ↓`     | `Cmd + Option + ↓`      |
# | Add Cursor Above       | `Ctrl + Alt + ↑`     | `Cmd + Option + ↑`      |
# | Select Next Occurrence | `Ctrl + D`           | `Cmd + D`               |
# | Select All Occurrences | `Ctrl + Shift + L`   | `Cmd + Shift + L`       |
# | Column (Box) Selection | `Shift + Alt + Drag` | `Shift + Option + Drag` |

# %% [markdown]
# ### <font face = 'Impact' color = '#1181C8' >Eagle Shadow - Search and Replace <font/>
# #### Scan the code like a hawk in the night. With Eagle Shadow, no variable hides, no typo escapes, and every replacement lands with deadly precision. Hunt, locate, and strike across your codebase — swift, silent, and unstoppable.
#
# | Action               | Windows / Linux    | macOS              |
# | -------------------- | ------------------ | ------------------ |
# | Find                 | `Ctrl + F`         | `Cmd + F`          |
# | Replace              | `Ctrl + H`         | `Cmd + Option + F` |
# | Find in Files        | `Ctrl + Shift + F` | `Cmd + Shift + F`  |
# | Replace in Files     | `Ctrl + Shift + H` | `Cmd + Shift + H`  |
# | Go to Line           | `Ctrl + G`         | `Ctrl + G`         |
# | Go to Symbol in File | `Ctrl + Shift + O` | `Cmd + Shift + O`  |

# %% [markdown]
# ## <font face = 'Impact' color = '#1181C8' >Silent Step -Code Navigation <font/>
# #### Move through your codebase like a shadow on the rooftops. With Silent Step, you can leap to definitions, peek into functions, and trace references without leaving a trace. Navigate swiftly, strike decisively, and never lose your place in the dojo of code.
#
# | Action             | Windows / Linux | macOS          |
# | ------------------ | --------------- | -------------- |
# | Go to Definition   | `F12`           | `F12`          |
# | Peek Definition    | `Alt + F12`     | `Option + F12` |
# | Go to References   | `Shift + F12`   | `Shift + F12`  |
# | Rename Symbol      | `F2`            | `F2`           |
# | Quick Fix          | `Ctrl + .`      | `Cmd + .`      |
# | Trigger Suggestion | `Ctrl + Space`  | `Ctrl + Space` |

# %% [markdown]
# ## <font face = 'Impact' color = '#1181C8' >Code Katana - Formatting & Refactoring <font/>
# #### Shape your code with the precision of a master blade. With Code Katana, every indentation is perfect, every function honed, and every refactor strikes cleanly. Transform messy code into a seamless work of stealth artistry, leaving no trace of disorder behind.
#
# | Action           | Windows / Linux     | macOS                |
# | ---------------- | ------------------- | -------------------- |
# | Format Document  | `Shift + Alt + F`   | `Shift + Option + F` |
# | Format Selection | `Ctrl + K Ctrl + F` | `Cmd + K Cmd + F`    |
# | Comment Line     | `Ctrl + /`          | `Cmd + /`            |
# | Block Comment    | `Shift + Alt + A`   | `Shift + Option + A` |
# | Fold             | `Ctrl + Shift + [`  | `Option + Cmd + [`   |
# | Unfold           | `Ctrl + Shift + ]`  | `Option + Cmd + ]`   |

# %% [markdown]
# ## <font face = 'Impact' color = '#1181C8' >Hidden Forge - Integrated Terminal <font/>
# #### The terminal is your secret forge, where commands are summoned and processes take shape. With Hidden Forge, you can wield the power of builds, run scripts, and execute code silently and efficiently. Fire, summon, and control your environment like a true shadow warrior.
#
# | Action          | Windows / Linux    | macOS             |
# | --------------- | ------------------ | ----------------- |
# | Toggle Terminal | `Ctrl + ~`         | `Ctrl + ~`        |
# | New Terminal    | `Ctrl + Shift + ~` | `Cmd + Shift + ~` |
# | Kill Terminal   | `Ctrl + Shift + W` | `Cmd + Shift + W` |

# %% [markdown]
# ## <font face = 'Impact' color = '#1181C8' >Shadow Rift - Split Editor & Tabs <font/>
# #### Move like a phantom between multiple scrolls at once. With Shadow Rift, you can open parallel views, jump between code sections, and monitor multiple layers of your project simultaneously. Your workspace becomes a silent battlefield where every tab, every split under your complete control.
#
# | Action                | Windows / Linux | macOS              |
# | --------------------- | --------------- | ------------------ |
# | Split Editor          | `Ctrl + \`      | `Cmd + \`          |
# | Focus Next Editor     | `Ctrl + 2`      | `Cmd + 2`          |
# | Focus Previous Editor | `Ctrl + 1`      | `Cmd + 1`          |
# | Navigate Tabs         | `Ctrl + Tab`    | `Cmd + Option + →` |

# %% [markdown]
# ## <font face = 'Impact' color = '#1181C8' >Ghost Strike - Debugging <font/>
# #### Hunt down elusive bugs like a shadow in the night. With Ghost Strike, you set breakpoints, step through your code silently, and uncover hidden errors with deadly precision. Every flaw revealed, every problem neutralized while your code remains flawless under the veil of stealth.
#
# | Action            | Windows / Linux | macOS         |
# | ----------------- | --------------- | ------------- |
# | Start Debugging   | `F5`            | `F5`          |
# | Stop              | `Shift + F5`    | `Shift + F5`  |
# | Toggle Breakpoint | `F9`            | `F9`          |
# | Step Over         | `F10`           | `F10`         |
# | Step Into         | `F11`           | `F11`         |
# | Step Out          | `Shift + F11`   | `Shift + F11` |

# %% [markdown]
# ## <font face = 'Impact' color = '#1181C8' >Mastery Scroll - Ultra Productivity Techniques <font/>
# #### These are the moves every coding ninja must engrain into muscle memory. With the Mastery Scroll, shortcuts become instinct, actions flow without thought, and you achieve maximum speed and precision. Memorize, practice, and execute... remember that true mastery is forged through repetition in the shadows.
#
# | Action           | Windows / Linux    | macOS             |
# | ---------------- | ------------------ | ----------------- |
# | Zen Mode         | `Ctrl + K Z`       | `Cmd + K Z`       |
# | Toggle Word Wrap | `Alt + Z`          | `Option + Z`      |
# | Open Extensions  | `Ctrl + Shift + X` | `Cmd + Shift + X` |
# | Show Problems    | `Ctrl + Shift + M` | `Cmd + Shift + M` |
# | Emmet Expand     | `Tab`              | `Tab`             |
